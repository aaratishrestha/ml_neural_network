# %% [markdown]
# <a href="https://colab.research.google.com/github/aaratishrestha/ml_neural_network/blob/main/kaggle_merch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
fileDownloaded = drive.CreateFile({'id':'1NUPn3SDU7aSw0LLc1DTa5x_WVKb4zcu2'})

# %%
fileDownloaded.GetContentFile('train.csv')

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    row_id        date  country       store         product  num_sold
# 0       0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1       1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2       2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3       3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4       4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911

# %%
df.dropna(inplace = True)
date_split = df["date"].str.split("-", n = 2, expand = False)
date_split
year = list()
month = list()
day = list()
for x in date_split:
  year.append(int(x[0]))
  month.append(int(x[1]))
  day.append(int(x[2]))

df['year'] = year
df['month'] = month
df['day'] = day
df.head()
# Out:
#    row_id        date  country       store         product  num_sold  year  \
# 0       0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329  2015
# 1       1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520  2015
# 2       2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146  2015
# 3       3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572  2015
# 4       4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911  2015
#
#    month  day
# 0      1    1
# 1      1    1
# 2      1    1
# 3      1    1
# 4      1    1

# %%
df.to_csv('data_by_day.csv')

# %%
df.loc[df['day'].mod(7) == 0, 'week'] = df['day'].floordiv(7)
df.loc[df['day'].mod(7) != 0, 'week'] = df['day'].floordiv(7)+1
df['week'] = df['week'].astype('int')
df.head()
# Out:
#    row_id        date  country       store         product  num_sold  year  \
# 0       0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329  2015
# 1       1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520  2015
# 2       2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146  2015
# 3       3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572  2015
# 4       4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911  2015
#
#    month  day  week
# 0      1    1     1
# 1      1    1     1
# 2      1    1     1
# 3      1    1     1
# 4      1    1     1

# %%
df_group_by_week = df.groupby(['year','month','week','country','product','store']).agg({'num_sold': 'sum'}).reset_index()
df_week = pd.DataFrame(data=df_group_by_week)
unique_week  = set(df_week['week'].to_list())
countries = ['Finland', 'Norway', 'Sweden']
stores = ['KaggleMart', 'KaggleRama']
products = ['Kaggle Hat', 'Kaggle Mug', 'Kaggle Sticker']
for week in unique_week:
  for country in countries:
    for store in stores:
      for product in products:
        df_by_week = df_week.loc[(df_week['week'] == week) & (df_week['country'] == country) & (df_week['store'] == store) & (df_week['product'] == product)]
        df_by_week.to_csv('week_'+str(week)+'_'+country+'_'+store+'_'+product+'.csv')

# %%
df_group_by_week = df.groupby(['year','month','week','country','product','store']).agg({'num_sold': 'sum'}).reset_index()
df_week = pd.DataFrame(data=df_group_by_week)
unique_week  = set(df_week['week'].to_list())
countries = ['Finland', 'Norway', 'Sweden']
stores = ['KaggleMart', 'KaggleRama']
products = ['Kaggle Hat', 'Kaggle Mug', 'Kaggle Sticker']
for week in unique_week:
  for country in countries:
    for store in stores:
      for product in products:
        df_by_week = df_week.loc[(df_week['week'] == week) & (df_week['country'] == country) & (df_week['store'] == store) & (df_week['product'] == product)]
        df_by_week.to_csv(str(week)+'_'+country+'_'+store+'_'+product+'.csv')

# %%
df_group_by_year = df.groupby(['year','country','product','store']).agg({'num_sold': 'sum'}).reset_index()
df_year = pd.DataFrame(data=df_group_by_year)
unique_year  = set(df_year['year'].to_list())
countries = ['Finland', 'Norway', 'Sweden']
stores = ['KaggleMart', 'KaggleRama']
products = ['Kaggle Hat', 'Kaggle Mug', 'Kaggle Sticker']
for year in unique_year:
  for country in countries:
    for store in stores:
      for product in products:
        df_by_year = df_year.loc[(df_year['year'] == year) & (df_year['country'] == country) & (df_year['store'] == store) & (df_year['product'] == product)]
        df_by_year.to_csv('year_'+str(year)+'_'+country+'_'+store+'_'+product+'.csv')

# %%
df_group_by_month = df.groupby(['year','month','country','product','store']).agg({'num_sold': 'sum'}).reset_index()
df_month = pd.DataFrame(data=df_group_by_month)
unique_month  = set(df_month['month'].to_list())
countries = ['Finland', 'Norway', 'Sweden']
stores = ['KaggleMart', 'KaggleRama']
products = ['Kaggle Hat', 'Kaggle Mug', 'Kaggle Sticker']
for month in unique_month:
  for country in countries:
    for store in stores:
      for product in products:
        df_by_month = df_month.loc[(df_month['month'] == month) & (df_month['country'] == country) & (df_month['store'] == store) & (df_month['product'] == product)]
        df_by_month.to_csv('month_'+str(month)+'_'+country+'_'+store+'_'+product+'.csv')

# %%
df_group_by_month = df.groupby(['year','month','country','product','store']).agg({'num_sold': 'sum'})
unique_month  = set(df_['week'].to_list())
pd.DataFrame(data=df_group_by_month).to_csv('data_by_month.csv')

# %%
df_group_by_year = df.groupby(['year','country','product','store']).agg({'num_sold': 'sum'})
pd.DataFrame(data=df_group_by_year).to_csv('data_by_year.csv')

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# '1_Finland_KaggleMart_Kaggle Mug.csv'
# '1_Finland_KaggleMart_Kaggle Sticker.csv'
# '1_Finland_KaggleRama_Kaggle Hat.csv'
# '1_Finland_KaggleRama_Kaggle Mug.csv'
# '1_Finland_KaggleRama_Kaggle Sticker.csv'
# '1_Norway_KaggleMart_Kaggle Hat.csv'
# '1_Norway_KaggleMart_Kaggle Mug.csv'
# '1_Norway_KaggleMart_Kaggle Sticker.csv'
# '1_Norway_KaggleRama_Kaggle Hat.csv'
# '1_Norway_KaggleRama_Kaggle Mug.csv'
# '1_Norway_KaggleRama_Kaggle Sticker.csv'
# '1_Sweden_KaggleMart_Kaggle Hat.csv'
# '1_Sweden_KaggleMart_Kaggle Mug.csv'
# '1_Sweden_KaggleMart_Kaggle Sticker.csv'
# '1_Sweden_KaggleRama_Kaggle Hat.csv'
# '1_Sweden_KaggleRama_Kaggle Mug.csv'
# '1_Sweden_KaggleRama_Kaggle Sticker.csv'
# '2_Finland_KaggleMart_Kaggle Hat.csv'
# '2_Finland_KaggleMart_Kaggle Mug.csv'
# '2_Finland_KaggleMart_Kaggle Sticker.csv'
# '2_Finland_KaggleRama_Kaggle Hat.csv'
# '2_Finland_KaggleRama_Kaggle Mug.csv'
# '2_Finland_KaggleRama_Kaggle Sticker.csv'
# '2_Norway_KaggleMart_Kaggle Hat.csv'
# '2_Norway_KaggleMart_Kaggle Mug.csv'
# '2_Norway_KaggleMart_Kaggle Sticker.csv'
# '2_Norway_KaggleRama_Kaggle Hat.csv'
# '2_Norway_KaggleRama_Kaggle Mug.csv'
# '2_Norway_KaggleRama_Kaggle Sticker.csv'
# '2_Sweden_KaggleMart_Kaggle Hat.csv'
# '2_Sweden_KaggleMart_Kaggle Mug.csv'
# '2_Sweden_KaggleMart_Kaggle Sticker.csv'
# '2_Sweden_KaggleRama_Kaggle Hat.csv'
# '2_Sweden_KaggleRama_Kaggle Mug.csv'
# '2_Sweden_KaggleRama_Kaggle Sticker.csv'
# '3_Finland_KaggleMart_Kaggle Hat.csv'
# '3_Finland_KaggleMart_Kaggle Mug.csv'
# '3_Finland_KaggleMart_Kaggle Sticker.csv'
# '3_Finland_KaggleRama_Kaggle Hat.csv'
# '3_Finland_KaggleRama_Kaggle Mug.csv'
# '3_Finland_KaggleRama_Kaggle Sticker.csv'
# '3_Norway_KaggleMart_Kaggle Hat.csv'
# '3_Norway_KaggleMart_Kaggle Mug.csv'
# '3_Norway_KaggleMart_Kaggle Sticker.csv'
# '3_Norway_KaggleRama_Kaggle Hat.csv'
# '3_Norway_KaggleRama_Kaggle Mug.csv'
# '3_Norway_KaggleRama_Kaggle Sticker.csv'
# '3_Sweden_KaggleMart_Kaggle Hat.csv'
# '3_Sweden_KaggleMart_Kaggle Mug.csv'
# '3_Sweden_KaggleMart_Kaggle Sticker.csv'
# '3_Sweden_KaggleRama_Kaggle Hat.csv'
# '3_Sweden_KaggleRama_Kaggle Mug.csv'
# '3_Sweden_KaggleRama_Kaggle Sticker.csv'
# '4_Finland_KaggleMart_Kaggle Hat.csv'
# '4_Finland_KaggleMart_Kaggle Mug.csv'
# '4_Finland_KaggleMart_Kaggle Sticker.csv'
# '4_Finland_KaggleRama_Kaggle Hat.csv'
# '4_Finland_KaggleRama_Kaggle Mug.csv'
# '4_Finland_KaggleRama_Kaggle Sticker.csv'
# '4_Norway_KaggleMart_Kaggle Hat.csv'
# '4_Norway_KaggleMart_Kaggle Mug.csv'
# '4_Norway_KaggleMart_Kaggle Sticker.csv'
# '4_Norway_KaggleRama_Kaggle Hat.csv'
# '4_Norway_KaggleRama_Kaggle Mug.csv'
# '4_Norway_KaggleRama_Kaggle Sticker.csv'
# '4_Sweden_KaggleMart_Kaggle Hat.csv'
# '4_Sweden_KaggleMart_Kaggle Mug.csv'
# '4_Sweden_KaggleMart_Kaggle Sticker.csv'
# '4_Sweden_KaggleRama_Kaggle Hat.csv'
# '4_Sweden_KaggleRama_Kaggle Mug.csv'
# '4_Sweden_KaggleRama_Kaggle Sticker.csv'
# '5_Finland_KaggleMart_Kaggle Hat.csv'
# '5_Finland_KaggleMart_Kaggle Mug.csv'
# '5_Finland_KaggleMart_Kaggle Sticker.csv'
# '5_Finland_KaggleRama_Kaggle Hat.csv'
# '5_Finland_KaggleRama_Kaggle Mug.csv'
# '5_Finland_KaggleRama_Kaggle Sticker.csv'
# '5_Norway_KaggleMart_Kaggle Hat.csv'
# '5_Norway_KaggleMart_Kaggle Mug.csv'
# '5_Norway_KaggleMart_Kaggle Sticker.csv'
# '5_Norway_KaggleRama_Kaggle Hat.csv'
# '5_Norway_KaggleRama_Kaggle Mug.csv'
# '5_Norway_KaggleRama_Kaggle Sticker.csv'
# '5_Sweden_KaggleMart_Kaggle Hat.csv'
# '5_Sweden_KaggleMart_Kaggle Mug.csv'
# '5_Sweden_KaggleMart_Kaggle Sticker.csv'
# '5_Sweden_KaggleRama_Kaggle Hat.csv'
# '5_Sweden_KaggleRama_Kaggle Mug.csv'
# '5_Sweden_KaggleRama_Kaggle Sticker.csv'
#  data_by_day.csv
#  data_by_month.csv
#  data_by_year.csv
# 'month_10_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_10_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_10_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_10_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_10_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_10_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_10_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_10_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_10_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_10_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_10_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_10_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_10_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_10_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_10_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_10_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_10_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_10_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_11_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_11_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_11_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_11_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_11_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_11_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_11_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_11_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_11_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_11_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_11_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_11_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_11_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_11_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_11_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_11_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_11_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_11_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_12_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_12_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_12_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_12_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_12_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_12_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_12_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_12_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_12_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_12_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_12_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_12_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_12_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_12_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_12_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_12_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_12_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_12_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_1_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_1_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_1_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_1_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_1_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_1_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_1_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_1_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_1_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_1_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_1_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_1_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_1_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_1_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_1_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_1_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_1_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_1_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_2_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_2_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_2_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_2_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_2_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_2_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_2_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_2_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_2_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_2_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_2_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_2_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_2_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_2_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_2_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_2_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_2_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_2_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_3_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_3_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_3_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_3_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_3_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_3_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_3_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_3_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_3_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_3_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_3_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_3_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_3_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_3_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_3_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_3_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_3_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_3_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_4_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_4_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_4_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_4_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_4_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_4_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_4_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_4_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_4_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_4_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_4_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_4_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_4_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_4_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_4_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_4_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_4_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_4_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_5_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_5_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_5_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_5_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_5_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_5_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_5_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_5_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_5_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_5_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_5_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_5_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_5_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_5_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_5_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_5_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_5_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_5_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_6_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_6_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_6_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_6_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_6_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_6_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_6_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_6_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_6_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_6_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_6_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_6_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_6_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_6_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_6_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_6_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_6_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_6_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_7_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_7_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_7_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_7_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_7_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_7_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_7_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_7_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_7_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_7_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_7_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_7_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_7_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_7_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_7_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_7_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_7_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_7_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_8_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_8_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_8_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_8_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_8_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_8_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_8_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_8_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_8_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_8_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_8_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_8_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_8_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_8_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_8_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_8_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_8_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_8_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'month_9_Finland_KaggleMart_Kaggle Hat.csv'
# 'month_9_Finland_KaggleMart_Kaggle Mug.csv'
# 'month_9_Finland_KaggleMart_Kaggle Sticker.csv'
# 'month_9_Finland_KaggleRama_Kaggle Hat.csv'
# 'month_9_Finland_KaggleRama_Kaggle Mug.csv'
# 'month_9_Finland_KaggleRama_Kaggle Sticker.csv'
# 'month_9_Norway_KaggleMart_Kaggle Hat.csv'
# 'month_9_Norway_KaggleMart_Kaggle Mug.csv'
# 'month_9_Norway_KaggleMart_Kaggle Sticker.csv'
# 'month_9_Norway_KaggleRama_Kaggle Hat.csv'
# 'month_9_Norway_KaggleRama_Kaggle Mug.csv'
# 'month_9_Norway_KaggleRama_Kaggle Sticker.csv'
# 'month_9_Sweden_KaggleMart_Kaggle Hat.csv'
# 'month_9_Sweden_KaggleMart_Kaggle Mug.csv'
# 'month_9_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'month_9_Sweden_KaggleRama_Kaggle Hat.csv'
# 'month_9_Sweden_KaggleRama_Kaggle Mug.csv'
# 'month_9_Sweden_KaggleRama_Kaggle Sticker.csv'
#  sample_data
#  train.csv
# 'week_1_Finland_KaggleMart_Kaggle Hat.csv'
# 'week_1_Finland_KaggleMart_Kaggle Mug.csv'
# 'week_1_Finland_KaggleMart_Kaggle Sticker.csv'
# 'week_1_Finland_KaggleRama_Kaggle Hat.csv'
# 'week_1_Finland_KaggleRama_Kaggle Mug.csv'
# 'week_1_Finland_KaggleRama_Kaggle Sticker.csv'
# 'week_1_Norway_KaggleMart_Kaggle Hat.csv'
# 'week_1_Norway_KaggleMart_Kaggle Mug.csv'
# 'week_1_Norway_KaggleMart_Kaggle Sticker.csv'
# 'week_1_Norway_KaggleRama_Kaggle Hat.csv'
# 'week_1_Norway_KaggleRama_Kaggle Mug.csv'
# 'week_1_Norway_KaggleRama_Kaggle Sticker.csv'
# 'week_1_Sweden_KaggleMart_Kaggle Hat.csv'
# 'week_1_Sweden_KaggleMart_Kaggle Mug.csv'
# 'week_1_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'week_1_Sweden_KaggleRama_Kaggle Hat.csv'
# 'week_1_Sweden_KaggleRama_Kaggle Mug.csv'
# 'week_1_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'week_2_Finland_KaggleMart_Kaggle Hat.csv'
# 'week_2_Finland_KaggleMart_Kaggle Mug.csv'
# 'week_2_Finland_KaggleMart_Kaggle Sticker.csv'
# 'week_2_Finland_KaggleRama_Kaggle Hat.csv'
# 'week_2_Finland_KaggleRama_Kaggle Mug.csv'
# 'week_2_Finland_KaggleRama_Kaggle Sticker.csv'
# 'week_2_Norway_KaggleMart_Kaggle Hat.csv'
# 'week_2_Norway_KaggleMart_Kaggle Mug.csv'
# 'week_2_Norway_KaggleMart_Kaggle Sticker.csv'
# 'week_2_Norway_KaggleRama_Kaggle Hat.csv'
# 'week_2_Norway_KaggleRama_Kaggle Mug.csv'
# 'week_2_Norway_KaggleRama_Kaggle Sticker.csv'
# 'week_2_Sweden_KaggleMart_Kaggle Hat.csv'
# 'week_2_Sweden_KaggleMart_Kaggle Mug.csv'
# 'week_2_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'week_2_Sweden_KaggleRama_Kaggle Hat.csv'
# 'week_2_Sweden_KaggleRama_Kaggle Mug.csv'
# 'week_2_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'week_3_Finland_KaggleMart_Kaggle Hat.csv'
# 'week_3_Finland_KaggleMart_Kaggle Mug.csv'
# 'week_3_Finland_KaggleMart_Kaggle Sticker.csv'
# 'week_3_Finland_KaggleRama_Kaggle Hat.csv'
# 'week_3_Finland_KaggleRama_Kaggle Mug.csv'
# 'week_3_Finland_KaggleRama_Kaggle Sticker.csv'
# 'week_3_Norway_KaggleMart_Kaggle Hat.csv'
# 'week_3_Norway_KaggleMart_Kaggle Mug.csv'
# 'week_3_Norway_KaggleMart_Kaggle Sticker.csv'
# 'week_3_Norway_KaggleRama_Kaggle Hat.csv'
# 'week_3_Norway_KaggleRama_Kaggle Mug.csv'
# 'week_3_Norway_KaggleRama_Kaggle Sticker.csv'
# 'week_3_Sweden_KaggleMart_Kaggle Hat.csv'
# 'week_3_Sweden_KaggleMart_Kaggle Mug.csv'
# 'week_3_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'week_3_Sweden_KaggleRama_Kaggle Hat.csv'
# 'week_3_Sweden_KaggleRama_Kaggle Mug.csv'
# 'week_3_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'week_4_Finland_KaggleMart_Kaggle Hat.csv'
# 'week_4_Finland_KaggleMart_Kaggle Mug.csv'
# 'week_4_Finland_KaggleMart_Kaggle Sticker.csv'
# 'week_4_Finland_KaggleRama_Kaggle Hat.csv'
# 'week_4_Finland_KaggleRama_Kaggle Mug.csv'
# 'week_4_Finland_KaggleRama_Kaggle Sticker.csv'
# 'week_4_Norway_KaggleMart_Kaggle Hat.csv'
# 'week_4_Norway_KaggleMart_Kaggle Mug.csv'
# 'week_4_Norway_KaggleMart_Kaggle Sticker.csv'
# 'week_4_Norway_KaggleRama_Kaggle Hat.csv'
# 'week_4_Norway_KaggleRama_Kaggle Mug.csv'
# 'week_4_Norway_KaggleRama_Kaggle Sticker.csv'
# 'week_4_Sweden_KaggleMart_Kaggle Hat.csv'
# 'week_4_Sweden_KaggleMart_Kaggle Mug.csv'
# 'week_4_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'week_4_Sweden_KaggleRama_Kaggle Hat.csv'
# 'week_4_Sweden_KaggleRama_Kaggle Mug.csv'
# 'week_4_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'week_5_Finland_KaggleMart_Kaggle Hat.csv'
# 'week_5_Finland_KaggleMart_Kaggle Mug.csv'
# 'week_5_Finland_KaggleMart_Kaggle Sticker.csv'
# 'week_5_Finland_KaggleRama_Kaggle Hat.csv'
# 'week_5_Finland_KaggleRama_Kaggle Mug.csv'
# 'week_5_Finland_KaggleRama_Kaggle Sticker.csv'
# 'week_5_Norway_KaggleMart_Kaggle Hat.csv'
# 'week_5_Norway_KaggleMart_Kaggle Mug.csv'
# 'week_5_Norway_KaggleMart_Kaggle Sticker.csv'
# 'week_5_Norway_KaggleRama_Kaggle Hat.csv'
# 'week_5_Norway_KaggleRama_Kaggle Mug.csv'
# 'week_5_Norway_KaggleRama_Kaggle Sticker.csv'
# 'week_5_Sweden_KaggleMart_Kaggle Hat.csv'
# 'week_5_Sweden_KaggleMart_Kaggle Mug.csv'
# 'week_5_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'week_5_Sweden_KaggleRama_Kaggle Hat.csv'
# 'week_5_Sweden_KaggleRama_Kaggle Mug.csv'
# 'week_5_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'year_2015_Finland_KaggleMart_Kaggle Hat.csv'
# 'year_2015_Finland_KaggleMart_Kaggle Mug.csv'
# 'year_2015_Finland_KaggleMart_Kaggle Sticker.csv'
# 'year_2015_Finland_KaggleRama_Kaggle Hat.csv'
# 'year_2015_Finland_KaggleRama_Kaggle Mug.csv'
# 'year_2015_Finland_KaggleRama_Kaggle Sticker.csv'
# 'year_2015_Norway_KaggleMart_Kaggle Hat.csv'
# 'year_2015_Norway_KaggleMart_Kaggle Mug.csv'
# 'year_2015_Norway_KaggleMart_Kaggle Sticker.csv'
# 'year_2015_Norway_KaggleRama_Kaggle Hat.csv'
# 'year_2015_Norway_KaggleRama_Kaggle Mug.csv'
# 'year_2015_Norway_KaggleRama_Kaggle Sticker.csv'
# 'year_2015_Sweden_KaggleMart_Kaggle Hat.csv'
# 'year_2015_Sweden_KaggleMart_Kaggle Mug.csv'
# 'year_2015_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'year_2015_Sweden_KaggleRama_Kaggle Hat.csv'
# 'year_2015_Sweden_KaggleRama_Kaggle Mug.csv'
# 'year_2015_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'year_2016_Finland_KaggleMart_Kaggle Hat.csv'
# 'year_2016_Finland_KaggleMart_Kaggle Mug.csv'
# 'year_2016_Finland_KaggleMart_Kaggle Sticker.csv'
# 'year_2016_Finland_KaggleRama_Kaggle Hat.csv'
# 'year_2016_Finland_KaggleRama_Kaggle Mug.csv'
# 'year_2016_Finland_KaggleRama_Kaggle Sticker.csv'
# 'year_2016_Norway_KaggleMart_Kaggle Hat.csv'
# 'year_2016_Norway_KaggleMart_Kaggle Mug.csv'
# 'year_2016_Norway_KaggleMart_Kaggle Sticker.csv'
# 'year_2016_Norway_KaggleRama_Kaggle Hat.csv'
# 'year_2016_Norway_KaggleRama_Kaggle Mug.csv'
# 'year_2016_Norway_KaggleRama_Kaggle Sticker.csv'
# 'year_2016_Sweden_KaggleMart_Kaggle Hat.csv'
# 'year_2016_Sweden_KaggleMart_Kaggle Mug.csv'
# 'year_2016_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'year_2016_Sweden_KaggleRama_Kaggle Hat.csv'
# 'year_2016_Sweden_KaggleRama_Kaggle Mug.csv'
# 'year_2016_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'year_2017_Finland_KaggleMart_Kaggle Hat.csv'
# 'year_2017_Finland_KaggleMart_Kaggle Mug.csv'
# 'year_2017_Finland_KaggleMart_Kaggle Sticker.csv'
# 'year_2017_Finland_KaggleRama_Kaggle Hat.csv'
# 'year_2017_Finland_KaggleRama_Kaggle Mug.csv'
# 'year_2017_Finland_KaggleRama_Kaggle Sticker.csv'
# 'year_2017_Norway_KaggleMart_Kaggle Hat.csv'
# 'year_2017_Norway_KaggleMart_Kaggle Mug.csv'
# 'year_2017_Norway_KaggleMart_Kaggle Sticker.csv'
# 'year_2017_Norway_KaggleRama_Kaggle Hat.csv'
# 'year_2017_Norway_KaggleRama_Kaggle Mug.csv'
# 'year_2017_Norway_KaggleRama_Kaggle Sticker.csv'
# 'year_2017_Sweden_KaggleMart_Kaggle Hat.csv'
# 'year_2017_Sweden_KaggleMart_Kaggle Mug.csv'
# 'year_2017_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'year_2017_Sweden_KaggleRama_Kaggle Hat.csv'
# 'year_2017_Sweden_KaggleRama_Kaggle Mug.csv'
# 'year_2017_Sweden_KaggleRama_Kaggle Sticker.csv'
# 'year_2018_Finland_KaggleMart_Kaggle Hat.csv'
# 'year_2018_Finland_KaggleMart_Kaggle Mug.csv'
# 'year_2018_Finland_KaggleMart_Kaggle Sticker.csv'
# 'year_2018_Finland_KaggleRama_Kaggle Hat.csv'
# 'year_2018_Finland_KaggleRama_Kaggle Mug.csv'
# 'year_2018_Finland_KaggleRama_Kaggle Sticker.csv'
# 'year_2018_Norway_KaggleMart_Kaggle Hat.csv'
# 'year_2018_Norway_KaggleMart_Kaggle Mug.csv'
# 'year_2018_Norway_KaggleMart_Kaggle Sticker.csv'
# 'year_2018_Norway_KaggleRama_Kaggle Hat.csv'
# 'year_2018_Norway_KaggleRama_Kaggle Mug.csv'
# 'year_2018_Norway_KaggleRama_Kaggle Sticker.csv'
# 'year_2018_Sweden_KaggleMart_Kaggle Hat.csv'
# 'year_2018_Sweden_KaggleMart_Kaggle Mug.csv'
# 'year_2018_Sweden_KaggleMart_Kaggle Sticker.csv'
# 'year_2018_Sweden_KaggleRama_Kaggle Hat.csv'
# 'year_2018_Sweden_KaggleRama_Kaggle Mug.csv'
# 'year_2018_Sweden_KaggleRama_Kaggle Sticker.csv'

# %%
# !rm data_by_year.csv

# %%
# !zip -r dataset.zip . --ignore=sample_data
# Out:
# zip error: Invalid command arguments (long option 'ignore' not supported)

# %%
# !ls *.zip
# Out:
# dataset.zip

# %%
week_{{number}}_{{country_name}}_{kaggle_outlet}_{merchandise}.csv
